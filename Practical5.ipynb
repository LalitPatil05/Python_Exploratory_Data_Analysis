# %%
# calculate the percetile, mean and standard deviation of the appropriate columns

from sklearn.datasets import load_iris
import pandas as pd
import seaborn as sns

data = load_iris()
df = pd.DataFrame(data.data, columns=data.feature_names)

# Preprocessing
df = df.dropna()

#outlier removal
Q1=df.quantile(0.25)
Q3=df.quantile(0.75)
IQR=Q3-Q1
df=df[~((df < (Q1-1.5*IQR))|( df > (Q3+1.5*IQR))).any(axis=1)]

#percentile ,mean and standard deviation
print("Mean:\n", df.mean())
print("Percentile:\n", df.quantile(0.5))
print("Std:\n", df.std())

#visiaulization
sns.boxplot(data=df)
plt.show()
sns.histplot(df[df.columns[0]], kde=True)
plt.show()
sns.scatterplot(x=df.columns[0], y=df.columns[1], data=df)
plt.show()
sns.pairplot(df)
# Out:
# Mean:
#  sepal length (cm)    5.856849
# sepal width (cm)     3.040411
# petal length (cm)    3.806849
# petal width (cm)     1.220548
# dtype: float64
# Percentile:
#  sepal length (cm)    5.8
# sepal width (cm)     3.0
# petal length (cm)    4.4
# petal width (cm)     1.3
# Name: 0.5, dtype: float64
# Std:
#  sepal length (cm)    0.834093
# sepal width (cm)     0.397853
# petal length (cm)    1.758042
# petal width (cm)     0.759393
# dtype: float64
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 26
#      24 #visiaulization
#      25 sns.boxplot(data=df)
# ---> 26 plt.show()
#      27 sns.histplot(df[df.columns[0]], kde=True)
#      28 plt.show()
#
# NameError: name 'plt' is not defined
