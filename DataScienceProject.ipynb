# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as mlt
# %matplotlib inline
import seaborn as sns

print("Modules Imported Successfully..!!")
# Out:
# Modules Imported Successfully..!!

# %%
df = pd.read_csv('Diwali Sales Data.csv', encoding = 'unicode_escape')
print("Dataset Loaded Successfully..!!")
# Out:
# Dataset Loaded Successfully..!!

# %%
df.shape 
# Used for know the how many rows and columns present in the given data set
print("Rows in the Dataset : ",df.shape[0])
print("Columns in the Dataset :",df.shape[1])
# Out:
# Rows in the Dataset :  11251
# Columns in the Dataset : 15

# %%
df.head() # Used for view the 5 top most rows in the given dataset 
# you can also pass the number in the function that how many rows are wanted.
# for e.g. df.head(25) it will return top 25 rows
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders  \
# 0     Maharashtra   Western       Healthcare             Auto       1
# 1  Andhra Pradesh  Southern             Govt             Auto       3
# 2   Uttar Pradesh   Central       Automobile             Auto       3
# 3       Karnataka  Southern     Construction             Auto       2
# 4         Gujarat   Western  Food Processing             Auto       2
#
#     Amount  Status  unnamed1
# 0  23952.0     NaN       NaN
# 1  23934.0     NaN       NaN
# ...

# %%
df.info() # it return the all the details of the dataset
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  str
#  2   Product_ID        11251 non-null  str
#  3   Gender            11251 non-null  str
#  4   Age Group         11251 non-null  str
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  str
#  8   Zone              11251 non-null  str
#  9   Occupation        11251 non-null  str
#  10  Product_Category  11251 non-null  str
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), str(8)
# memory usage: 1.3 MB

# %%
df.drop(['Status', 'unnamed1'], axis=1, inplace=True)
# used for drop unrelated/blank columns into the dataset
# inplace=True is used for do the modification at the same time or line.
print("Columns Droped Successfully...!!")
df.info()
# Out:
# Columns Droped Successfully...!!
# <class 'pandas.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  str
#  2   Product_ID        11251 non-null  str
#  3   Gender            11251 non-null  str
#  4   Age Group         11251 non-null  str
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  str
#  8   Zone              11251 non-null  str
#  9   Occupation        11251 non-null  str
#  10  Product_Category  11251 non-null  str
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
# dtypes: float64(1), int64(4), str(8)
# memory usage: 1.1 MB

# %%
pd.isnull(df).sum()
# used for calculate the total null rows or values into the given dataset
# Out:
# User_ID              0
# Cust_name            0
# Product_ID           0
# Gender               0
# Age Group            0
# Age                  0
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_Category     0
# Orders               0
# Amount              12
# dtype: int64

# %%
# df.dropna(inplace=True)
# used for drop null values into the dataset
print("Null Values Removed Successfully..!!")
pd.isnull(df).sum()
# Out:
# Null Values Removed Successfully..!!
# User_ID              0
# Cust_name            0
# Product_ID           0
# Gender               0
# Age Group            0
# Age                  0
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_Category     0
# Orders               0
# Amount              12
# dtype: int64

# %%
# Initialize list of Lists 
testset = [['Kunal', 1], ['Sumit', 2], ['Uday', 3], ['Lalit', ], ['Devyani', 5]]
print("List Created Successfully..!!")

# Create the pandas DataFrame using List 
df_test = pd.DataFrame(testset, columns=['Name', 'Age'])
print("DataFrame Created Successfully..!!")

print("DataFrame is : ")

print(df_test)
# Out:
# List Created Successfully..!!
# DataFrame Created Successfully..!!
# DataFrame is :
#       Name  Age
# 0    Kunal  1.0
# 1    Sumit  2.0
# 2     Uday  3.0
# 3    Lalit  NaN
# 4  Devyani  5.0

# %%
df_test
# Out:
#       Name  Age
# 0    Kunal  1.0
# 1    Sumit  2.0
# 2     Uday  3.0
# 3    Lalit  NaN
# 4  Devyani  5.0

# %%
df_test.dropna(inplace=True)
# used to eliminate the null records into the dataset
print("null records removed successfully...!!")
# Out:
# null records removed successfully...!!

# %%
df_test
# Out:
#       Name  Age
# 0    Kunal  1.0
# 1    Sumit  2.0
# 2     Uday  3.0
# 4  Devyani  5.0

# %%
df['Amount'] = df['Amount'].astype('double')
# used for change the data type of the particular column into the dataset
print("Data Type Changed Successfully..!!")
# Out:
# Data Type Changed Successfully..!!

# %%
# Check the Data type is modified or not 
print("Data type of amount column is : ")
df['Amount'].dtype
# Out:
# Data type of amount column is :
# dtype('float64')

# %%
# used for to see or check that which columns are present into the given dataset
print("Columns are : ")
df.columns
# Out:
# Columns are :
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='str')

# %%
# rename the columns
print("before renaming columns are : ")
df.columns
print("Column Renamed Successfully")
print("afer renaming columns are : ")
df.rename(columns = {'State':'State/UT'})
# Out:
# before renaming columns are :
# Column Renamed Successfully
# afer renaming columns are :
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# ...

# %%
# describe() method returns description of the data in the DataFrame
# i.e. count, mean, std, etc..

print("Description of DataFrame is : ")
df.describe()
# Out:
# Description of DataFrame is :
#             User_ID           Age  Marital_Status        Orders        Amount
# count  1.125100e+04  11251.000000    11251.000000  11251.000000  11239.000000
# mean   1.003004e+06     35.421207        0.420318      2.489290   9453.610858
# std    1.716125e+03     12.754122        0.493632      1.115047   5222.355869
# min    1.000001e+06     12.000000        0.000000      1.000000    188.000000
# 25%    1.001492e+06     27.000000        0.000000      1.500000   5443.000000
# 50%    1.003065e+06     33.000000        0.000000      2.000000   8109.000000
# 75%    1.004430e+06     43.000000        1.000000      3.000000  12675.000000
# max    1.006040e+06     92.000000        1.000000      4.000000  23952.000000

# %%
# apply or retrieve the specific column description by using the describe() method
df[['Age', 'Orders', 'Amount']].describe()
# Out:
#                 Age        Orders        Amount
# count  11251.000000  11251.000000  11239.000000
# mean      35.421207      2.489290   9453.610858
# std       12.754122      1.115047   5222.355869
# min       12.000000      1.000000    188.000000
# 25%       27.000000      1.500000   5443.000000
# 50%       33.000000      2.000000   8109.000000
# 75%       43.000000      3.000000  12675.000000
# max       92.000000      4.000000  23952.000000

# %% [markdown]
# # Exploratory Data Analysis

# %%
# View the Columns
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='str')

# %%
# plot the gender graph without labels

sns.countplot(x = 'Gender', data = df, hue='Gender')
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
# plor the gender grpah with labels

ax = sns.countplot(x='Gender', data=df, hue='Gender')

for bars in ax.containers:
    ax.bar_label(bars)

# %%
# plot the chart by using group by object
# plot the dataframe by the filtered data
df.groupby(['Gender'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)
# Out:
#   Gender    Amount
# 0      F  74335853
# 1      M  31913276

# %%
# plot the graph by using or based on group by into the columns

sales_report = df.groupby(['Gender'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.barplot(x='Gender',y='Amount', data=sales_report, hue='Gender')
# Out:
# <Axes: xlabel='Gender', ylabel='Amount'>

# %% [markdown]
# **from above graphs we can see that most of the buyers are female and even the purchasing power of females are greater than man**

# %%
# Hue :-
# - used for represent the menu item list in the ploted graph Like a Menu List (Legend)

sns.countplot(data=df, x='Age Group', hue='Gender')
# Out:
# <Axes: xlabel='Age Group', ylabel='count'>

# %%
# without hue 
sns.countplot(data=df, x='Age Group')
# Out:
# <Axes: xlabel='Age Group', ylabel='count'>

# %%
# plot the graph with values 

ax = sns.countplot(data=df, x='Age Group', hue='Gender')

for bars in ax.containers:
    ax.bar_label(bars)

# %%
# plot the barplot based on group by with total amount vs age group

sales_age = df.groupby(['Age Group'],as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False)

sns.barplot(x='Age Group',y='Amount',data=sales_age, hue='Age Group')
# Out:
# <Axes: xlabel='Age Group', ylabel='Amount'>

# %% [markdown]
# **From above we can see that most of the buyers are of age group between 26-35 years female**

# %%
# total number of orders from top 10 states

sales_state = df.groupby(['State'], as_index=False)['Orders'].sum().sort_values(by='Orders', ascending=False).head(10)
sns.set(rc={'figure.figsize' : (20,5)})
sns.barplot(data=sales_state, x = 'State', y='Orders', hue='State')
# Out:
# <Axes: xlabel='State', ylabel='Orders'>

# %%
Sales_State = df.groupby(['State'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False).head(10)
# used for plot the graph based Total Amount and Sales from top 10 States

sns.set(rc={'figure.figsize':(15,5)})
sns.barplot(data=Sales_State, x='State', y='Amount', hue='State')
# Out:
# <Axes: xlabel='State', ylabel='Amount'>

# %% [markdown]
# **From the Above graph we can see that unexpectedly most of the orders are form uttar pradesh, Maharashtra and karnataka respectively but total sales/amount is from up, karnataka and then Maharashatra**

# %%
ax = sns.countplot(data=df, x='Marital_Status', hue='Marital_Status')
for bars in ax.containers:
    ax.bar_label(bars)

# %%
# see the based on amount

sales_state = df.groupby(['Marital_Status', 'Gender'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)
sns.set(rc={'figure.figsize':(6,5)})
sns.barplot(data=sales_state, x='Marital_Status', y='Amount', hue='Gender')
# Out:
# <Axes: xlabel='Marital_Status', ylabel='Amount'>

# %% [markdown]
# **From Above Graph we can see that most of the buyers are married women and they have high purchasing power.**

# %% [markdown]
# ## Occupation Based

# %%
sns.set(rc={'figure.figsize':(20,5)})
ax=sns.countplot(data=df, x='Occupation', hue='Occupation')
for bars in ax.containers:
    ax.bar_label(bars)

# %%
# plot the graph according to state wise based on the occupation

saleState = df.groupby(['Occupation'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)
sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data=saleState, x='Occupation', y='Amount', hue='Occupation')
# Out:
# <Axes: xlabel='Occupation', ylabel='Amount'>

# %% [markdown]
# **from above graph we can see that most of the buyers are working in IT, Avition and HealthCare Sectors**

# %% [markdown]
# ## Product Category

# %%
sns.set(rc={'figure.figsize':(30,5)})
ax = sns.countplot(data = df, x = 'Product_Category', hue='Product_Category')

for bars in ax.containers:
    ax.bar_label(bars)

# %%
# Sorted the Data
SalesState = df.groupby(['Product_Category'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)
sns.barplot(data=SalesState, x='Product_Category', y='Amount', hue='Product_Category')
# Out:
# <Axes: xlabel='Product_Category', ylabel='Amount'>

# %% [markdown]
# **From above graph we can see that most of the product are from food, footwear and Electronics Category.**

# %%
# plot the graph accordind to Product Category and based on Orders

SalesState=df.groupby(['Product_Category'], as_index=False)['Orders'].sum().sort_values(by='Orders', ascending=False).head()
sns.set(rc={'figure.figsize' : (20,5)})
ax = sns.barplot(data = SalesState, x = 'Product_Category', y='Orders', hue='Product_Category')
for bars in ax.containers:
    ax.bar_label(bars)

# %%
fig1, ax1 = mlt.subplots(figsize = (12,7))
df.groupby('Product_ID')['Orders'].sum().nlargest(10).sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: xlabel='Product_ID'>

# %% [markdown]
# # Conclusion

# %% [markdown]
# **Married womens age group 26-35 years from UP, Maharashatra and Karnataka Working in IT, Aviation and HealthCare are More Likely to Buy Products from Food, Clothing and Electronics Category.**
