# %%
from sklearn.datasets import load_iris
import pandas as pd
from scipy import stats
data = load_iris()
df = pd.DataFrame(data.data, columns=data.feature_names)
# Preprocessing
df = df.dropna()
#outlier removal
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1
df1 = df[~((df < (Q1 - 1.5*IQR)) | (df > (Q3 + 1.5*IQR))).any(axis=1)]
col = df[df.columns[0]]
#statistical hypothesis
t, p = stats.ttest_1samp(col, col.mean())
print("T:", t)
print("P:", p)
#visulization
df.hist()
plt.show()
sns.boxplot(data=df)
